# %% [markdown]
# # Poker simulation game

# %% [markdown]
# ## TODO
# - Parse the code and develop theory for a hybrid agent (try to mimic proper GTO if possible)
# - Implement practical agent based on above theory step.
# - Simulate game structure
